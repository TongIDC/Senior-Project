# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
print(f'pymysql version: {pymysql.__version__}')
print(f'pandas version: {pd.__version__}')
# Out:
# pymysql version: 0.9.3
# pandas version: 0.23.4

# %%
def writetosql(predict_date,df):
    uid='root'
    pwd='password'
    host='localhost'
    port=3306
    db='test' #change db
    con_string=f'mysql+pymysql://{uid}@{host}:{port}/{db}'
    #con_string=f'mysql+pymysql://{uid}:{pwd}@{host}:{port}/{db}'
    print(f'connection string = {con_string}')
    con=create_engine(con_string)
    df.to_sql(predict_date,con)

# %%
def battdata(date):    
    now = date.replace("_","-") +' 00:00:00' #date = predict_date?
    uid='user'
    pwd='the_password'
    host='192.168.1.43'
    port=3306
    db='example' #change to consumption db
    con_string=f'mysql+pymysql://{uid}:{pwd}@{host}:{port}/{db}'
    #con_string=f'mysql+pymysql://{uid}:{pwd}@{host}:{port}/{db}'
    #print(f'connection string = {con_string}')
    con=create_engine(con_string)
    #con = create_engine('mysql+pymysql://guest:relational@relational.fit.cvut.cz:3306/imdb_small')
    sql = '''select Generation
             from 2018-11-01
             ''' #เปลี่ยนชื่อ table dbของพี่โอ๊คเป็นแบบrunยาว โดยใช้timestampกำกับ ให้เรียกผ่านtimestamp ออกมาเป็นค่าค่าหนึ่งเลย
    gen = pd.read_sql(sql, con)
    return percentbatt

# %%
sql = 
dfbatt =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b1aa8c303a36> in <module>
# ----> 1 dfbatt = battdata("2018_11_01")
#
# <ipython-input-4-b25f16ee82f6> in battdata(date)
#       9     #con_string=f'mysql+pymysql://{uid}:{pwd}@{host}:{port}/{db}'
#      10     #print(f'connection string = {con_string}')
# ---> 11     con=create_engine(con_string)
#      12     #con = create_engine('mysql+pymysql://guest:relational@relational.fit.cvut.cz:3306/imdb_small')
#      13     sql = '''select Generation
#
# NameError: name 'create_engine' is not defined

# %%
uid='tong'
pwd='the_password'
host='192.168.1.2'
port=3306
db='Chula' #change to consumption db
con_string=f'mysql+pymysql://{uid}:{pwd}@{host}:{port}/{db}'
#con_string=f'mysql+pymysql://{uid}:{pwd}@{host}:{port}/{db}'
#print(f'connection string = {con_string}')
con=create_engine(con_string)

# %%
con.table_names()
# Out:
# ['HEMS01', 'TEST']

# %%
2019-05-05 11:58:00
2018-01-28 22:30:00

# %%
SELECT * FROM subscription t WHERE t.active_time BETWEEN '2019-05-05 00:00:00' AND '2019-05-05 23:59:59';

# %%
sql = "SELECT * FROM HEMS01;"
df1 = pd.read_sql(sql,con)
df1
# Out:
#                  Date/Time  PV_Total  PV_Daily  PV_Power  Batt_SOC  Batt_Cap  \
# 0      2018-01-28 22:26:45      2336     16206         0        63        99
# 1      2018-01-28 22:27:00      2336     16206         0        63        99
# 2      2018-01-28 22:27:15      2336     16206         0        63        99
# 3      2018-01-28 22:27:30      2336     16206         0        63        99
# 4      2018-01-28 22:27:46      2336     16206         0        63        99
# 5      2018-01-28 22:28:00      2336     16206         0        63        99
# 6      2018-01-28 22:28:15      2336     16206         0        63        99
# 7      2018-01-28 22:28:30      2336        16         0        63        99
# 8      2018-01-28 22:28:45      2336        16         0        63        99
# 9      2018-01-28 22:29:15      2336     16206         0        63        99
# 10     2018-01-28 22:29:30      2336     16206         0        63        99
# 11     2018-01-28 22:29:46      2336     16206         0        63        99
# 12     2018-01-28 22:30:00      2336     16206         0        63        99
# 13     2018-01-28 22:30:15      2336     16206         0        63        99
# 14     2018-01-28 22:30:30      2336     16206         0        63        99
# 3             294       5030       0             0            0         0
# 4             294       5030       0             0            0         0
# 5             294       5030       0             0            0         0
# 6             294       5030       0             0            0         0
# 7              29         50       0             0            0         0
# 8              29         50       0             0            0         0
# 9             294       5030       0             0            0         0
# 10            294       5030       0             0            0         0
# 11            294       5030       0             0            0         0
# 12            294       5030       0             0            0         0
# 13            294       5030       0             0            0         0
# 14            294       5030       0             0            0         0
# 15            294       5030       0             0            0         0
# 16            294       5030       0             0            0         0
# 17            294       5030       0             0            0         0
# 18            294       5030       0             0            0         0
# 19            294       5030       0             0            0         0
# 20            294       5030       0             0            0         0
# 21            294       5030       0             0            0         0
# 22            294       5030       0             0            0         0
# 23            294       5030       0             0            0         0
# 24            294       5030       0             0            0         0
# 25            294       5030       0             0            0         0
# 26            294       5030       0             0            0         0
# 27            294       5030       0             0            0         0
# 28            294       5030       0             0            0         0
# 29            294       5030       0             0            0         0
# ...           ...        ...     ...           ...          ...       ...
# 180399        352       5260       6         19100         1000       410
# 180400        352       5260       6         19100         1000       410
# 180401        352       5260       6         19100         1000       410
# 180402        352       5260       6         19100         1000       410
# 180403        352       5320       0         19100         1000     64876
# 180404        352       5320       0         19100         1000     64876
# 180405        352       5320       0         19100         1000     64876
# 180406        352       5320       0         19100         1000     64876
# 180407        352       5610       0         19100         1000     64946
# 180408        352       5610       0         19100         1000     64946
# 180409        352       5610       0         19100         1000     64946
# 180410        352       5610       0         19100         1000     64946
# 180411        353       5610       0         19100         1000     65226
# 180412        353       5610       0         19100         1000     65226
# 180413        353       5610       0         19100         1000     65226
# 180414        353       5610       0         19100         1000     65226
# 180415        353       5610       0         19100         1000     65286
# 180416        353       5610       0         19100         1000     65286
# 180417        353       5610       0         19100         1000     65286
# 180418        353       5610       0         19100         1000     65286
# 180419        353       5170     982         19100         1000       990
# 180420        353       5170     982         19100         1000       990
# 180421        353       5170     982         19100         1000       990
# 180422        353       5170     982         19100         1000       990
# 180423        353       5140     789         19100         1000       740
# 180424        353       5140     789         19100         1000       740
# 180425        353       5140     789         19100         1000       740
# 180426        353       5140     789         19100         1000       740
# 180427        353       5140     772         19100         1000       770
# 180428        353       5140     772         19100         1000       770
#
# [180429 rows x 12 columns]

# %%
df1["Date/Time"]

# %%
df1.dtypes
# Out:
# Date/Time       datetime64[ns]
# PV_Total                 int64
# PV_Daily                 int64
# PV_Power                 int64
# Batt_SOC                 int64
# Batt_Cap                 int64
# Batt_Temp                int64
# Batt_Volt                int64
# P_Load                   int64
# E_Grid_Today             int64
# E_Fed_Today              int64
# R30775U5                 int64
# dtype: object

# %%
#con = create_engine('mysql+pymysql://guest:relational@relational.fit.cvut.cz:3306/imdb_small')
sql = '''select Generation
         from 2018-11-01
         ''' #เปลี่ยนชื่อ table dbของพี่โอ๊คเป็นแบบrunยาว โดยใช้timestampกำกับ ให้เรียกผ่านtimestamp ออกมาเป็นค่าค่าหนึ่งเลย
gen = pd.read_sql(sql, con)
return percentbatt
