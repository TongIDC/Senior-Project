# %%
import pandas as pd
import json

# %%
filename = "2019-04-13" #date

# %%
path = "Testdate/"
with open(path + filename + ".json", 'r', encoding='utf-8') as fin:
    data_json = json.loads(fin.read())

# %%
data_json
# Out:
# {'apparentTemperature': {'00:00': 92.9,
#   '00:15': 92.9,
#   '00:30': 92.9,
#   '00:45': 92.9,
#   '01:00': 96.21,
#   '01:15': 96.21,
#   '01:30': 96.21,
#   '01:45': 96.21,
#   '02:00': 99.85,
#   '02:15': 99.85,
#   '02:30': 99.85,
#   '02:45': 99.85,
#   '03:00': 101.15,
#   '03:15': 101.15,
#   '03:30': 101.15,
#   '03:45': 101.15,
#   '04:00': 101.22,
#   '04:15': 101.22,
#   '04:30': 101.22,
#   '04:45': 101.22,
#   '05:00': 100.81,
#   '05:15': 100.81,
#   '05:30': 100.81,
#   '05:45': 100.81,
#   '06:00': 100.19,
#   '06:15': 100.19,
#   '06:30': 100.19,
#   '06:45': 100.19,
#   '07:00': 99.57,
#   '07:15': 99.57,
#   '07:30': 99.57,
#   '07:45': 99.57,
#   '08:00': 98.95,
#   '08:15': 98.95,
#   '08:30': 98.95,
#   '08:45': 98.95,
#   '09:00': 98.78,
#   '09:15': 98.78,
#   '09:30': 98.78,
#   '09:45': 98.78,
#   '10:00': 99.27,
#   '10:15': 99.27,
#   '10:30': 99.27,
#   '10:45': 99.27,
#   '11:00': 97.76,
#   '11:15': 97.76,
#   '11:30': 97.76,
#   '11:45': 97.76,
# ...

# %%
testcalljsondf = pd.DataFrame.from_dict(data_json)
testcalljsondf
# Out:
#        apparentTemperature  cloudCover  dewPoint  humidity  \
# 00:00                92.90        0.39     77.41      0.83
# 00:15                92.90        0.39     77.41      0.83
# 00:30                92.90        0.39     77.41      0.83
# 00:45                92.90        0.39     77.41      0.83
# 01:00                96.21        0.36     76.46      0.74
# 01:15                96.21        0.36     76.46      0.74
# 01:30                96.21        0.36     76.46      0.74
# 01:45                96.21        0.36     76.46      0.74
# 02:00                99.85        0.32     75.24      0.64
# 02:15                99.85        0.32     75.24      0.64
# 02:30                99.85        0.32     75.24      0.64
# 02:45                99.85        0.32     75.24      0.64
# 03:00               101.15        0.37     73.99      0.57
# 03:15               101.15        0.37     73.99      0.57
# 03:30               101.15        0.37     73.99      0.57
# ...

# %%
testcalljsondf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96 entries, 00:00 to 23:45
# Data columns (total 17 columns):
# apparentTemperature    96 non-null float64
# cloudCover             96 non-null float64
# dewPoint               96 non-null float64
# humidity               96 non-null float64
# icon                   96 non-null object
# ozone                  96 non-null float64
# precipIntensity        96 non-null float64
# precipProbability      96 non-null float64
# precipType             0 non-null object
# pressure               96 non-null float64
# summary                96 non-null object
# temperature            96 non-null float64
# uvIndex                96 non-null int64
# visibility             96 non-null float64
# windBearing            96 non-null int64
# windGust               96 non-null float64
# windSpeed              96 non-null float64
# dtypes: float64(12), int64(2), object(3)
# memory usage: 13.5+ KB
